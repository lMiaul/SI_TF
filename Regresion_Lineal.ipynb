# %% [markdown]
# <a href="https://colab.research.google.com/github/lMiaul/SI_TF/blob/mauricio/Regresion_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/MyDrive/')
# Out:
# Mounted at /MyDrive/

# %%
import csv
import pandas as pd

# %%
#Carga de datos de la tabla a analizar con tildes
df = pd.read_csv('/MyDrive/MyDrive/Sistemas Inteligentes/B. Generación Anual de residuos municipal_Distrital_2014_2021_0_CT.csv', encoding='utf-8')
df.head(14980)
# Out:
#       FECHA_CORTE  N_SEC  UBIGEO REG_NAT DEPARTAMENTO    PROVINCIA  \
# 0       9/01/2023      1   10101   SELVA     AMAZONAS  CHACHAPOYAS
# 1       9/01/2023      2   10102   SELVA     AMAZONAS  CHACHAPOYAS
# 2       9/01/2023      3   10103  SIERRA     AMAZONAS  CHACHAPOYAS
# 3       9/01/2023      4   10104  SIERRA     AMAZONAS  CHACHAPOYAS
# 4       9/01/2023      5   10105  SIERRA     AMAZONAS  CHACHAPOYAS
# ...           ...    ...     ...     ...          ...          ...
# 14973   9/01/2023  14974  250304   SELVA      UCAYALI   PADRE ABAD
# 14974   9/01/2023  14975  250305   SELVA      UCAYALI   PADRE ABAD
# 14975   9/01/2023  14976  250306   SELVA      UCAYALI   PADRE ABAD
# 14976   9/01/2023  14977  250307   SELVA      UCAYALI   PADRE ABAD
# 14977   9/01/2023  14978  250401   SELVA      UCAYALI        PUR S
#
#                        DISTRITO  POB_TOTAL  POB_URBANA  POB_RURAL  \
# 0                   CHACHAPOYAS      28423       27548        875
# ...
